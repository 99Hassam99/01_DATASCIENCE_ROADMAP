# %% [markdown]
# # Project 1
#
# # Real Estate Price Prediction
#
# # Introduction
#
# We are going to start working on a real life data science project. We will see a glimpse of what kind of steps and challenges a data scientist working for a big company goes through in day-to-day life. Assume you are a data scientist working for a real estate company such as:
#
# Zillow.com here in US
#
# ![01.JPG](attachment:0a1c35c5-820a-4921-ba22-3b6e2b1a72b2.JPG)
#
# Or:
#
# Magicbricks.com
#
# ![02.JPG](attachment:6d5d2c53-0ed4-44ed-ab66-eda59957e6b4.JPG)
#
# And your business manager comes to you and ask you to build a model that can predict the property price based on certain features such as sqrft, bedrooms, bathroom and location etc. On Zillow.com this feature is already available as shown and they call it Zestimate and it shows you the Zillow estimated price:
#
# ![03.JPG](attachment:42ab92de-7288-444e-a064-ba18436a7b65.JPG)
#
# Just to make this project more enhanced we are also going to build a website using **HTML, CSS, Javascript** which will do home price prediction for you.
#
# ![04.JPG](attachment:9bc6535e-4578-405f-a147-9f8aa604c46b.JPG)
#
# In terms of project architecture first we are going to take home price dataset from Kaggle.com which is for Banglore city India.
#
# ![05.JPG](attachment:b0d0777c-fd01-4a3d-8a89-c93148e19ccc.JPG)
#
# And using that dataset we will build a machine learning model. While building the model we will cover some of the data science concepts such as:
#
# ![06.JPG](attachment:67818461-9e00-4fee-9d74-622f5776e8bf.JPG)
#
# Once the model is built then we will export it to a pickle file and then we will write a python flash server which can consume this pickle file and do price prediction for you.
#
# This python flash server will expose HTTP endpoints for various requests and the UI written in HTML CSS JAVASCRIPT will make HTTP GET and POST calls.
#
# ![07.JPG](attachment:d4315380-a131-425c-acd4-11eebed11f93.JPG)
#
# Interms of tools and technology we will use:
# 1. Python as programming language
# 2. Pandas for data cleaning
# 3. Matplotlib for data visualization
# 4. Sklearn for model building
# 5. Python flask for a backend server
# 6. HTML CSS JAVASCRIPT for website UI
#
# Overall we will learn alot and it will be a very interesting project.
#
# # Project Overview
#
# Regression Project: Bangalore property price prediction
#
# o Project covers following
#
# 1. Data cleaning
# 2. Feature engineering
# 3. Model building and hyper parameter tuning
# 4. Write flask server as a web backend
# 5. Building website for price prediction
# 6. Deployment to AWS
