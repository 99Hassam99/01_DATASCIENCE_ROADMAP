# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('01_iplauction.csv')
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.shape
# Out:
# (309, 7)

# %%
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
df.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.describe(include=['object','bool'])
# Out:
#               name player style nationality franchise    status
# count          309          309         309       238       309
# unique         309            4          14        10         3
# top     Axar Patel       Bowler       India        RR  RETAINED
# freq             1          111         201        25       158

# %%
df['status'].value_counts()
# Out:
# status
# RETAINED    158
# SOLD         80
# UNSOLD       71
# Name: count, dtype: int64

# %%
df['status'].value_counts(normalize=True)
# Out:
# status
# RETAINED    0.511327
# SOLD        0.258900
# UNSOLD      0.229773
# Name: proportion, dtype: float64

# %%
df.sort_values(by='base price (in lacs)',ascending=False).head()
# Out:
#                       name player style   nationality  base price (in lacs)  \
# 17   Rassie van der Dussen       Batter  South Africa                 200.0
# 129        Kane Williamson       Batter   New Zealand                 200.0
# 132           Jason Holder   Allrounder   West Indies                 200.0
# 148          Cameron Green   Allrounder     Australia                 200.0
# 87           James Neesham   Allrounder   New Zealand                 200.0
#
#      final price (in lacs) franchise  status
# 17                     NaN       NaN  UNSOLD
# 129                  200.0        GT    SOLD
# 132                  575.0        RR    SOLD
# 148                 1750.0        MI    SOLD
# 87                     NaN       NaN  UNSOLD

# %%
df.sort_values(by=['base price (in lacs)', "final price (in lacs)"], ascending=[True, False]).head()
# Out:
#                name player style nationality  base price (in lacs)  \
# 103    Mukesh Kumar       Bowler       India                  20.0
# 122  Vivrant Sharma   Allrounder       India                  20.0
# 74     Mayank Dagar   Allrounder       India                  20.0
# 112   Srikar Bharat    WK-Batter       India                  20.0
# 105    N Jagadeesan    WK-Batter       India                  20.0
#
#      final price (in lacs) franchise status
# 103                  550.0        DC   SOLD
# 122                  260.0       SRH   SOLD
# 74                   180.0       SRH   SOLD
# 112                  120.0        GT   SOLD
# 105                   90.0       KKR   SOLD

# %%
df['base price (in lacs)'].mean()
# Out:
# np.float64(59.205298013245034)

# %%
df[df['name'] == 10]["status"].mean()
# Out:
# nan

# %%
df.loc[0:5, "name":"nationality"]
# Out:
#               name player style   nationality
# 0     Harshit Rana       Bowler         India
# 1        Ekant Sen       Batter         India
# 2    Wayne Parnell   Allrounder  South Africa
# 3  Shakib Al Hasan   Allrounder    Bangladesh
# 4         Joe Root       Batter       England
# 5     Abdul Basith   Allrounder         India

# %%
df.iloc[0:6, 0:6]
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
# 5     Abdul Basith   Allrounder         India                  20.0
#
#    final price (in lacs) franchise
# 0                   20.0       KKR
# 1                    NaN       NaN
# 2                    NaN       NaN
# 3                  150.0       KKR
# 4                  100.0        RR
# 5                   20.0        RR

# %%
df[-1:]
# Out:
#            name player style nationality  base price (in lacs)  \
# 308  Axar Patel   Allrounder       India                   NaN
#
#      final price (in lacs) franchise    status
# 308                  900.0        DC  RETAINED

# %%
df[df["name"].apply(lambda state: state[0] == "V")].head(20)
# Out:
#                     name player style nationality  base price (in lacs)  \
# 44           Varun Aaron   Allrounder       India                  50.0
# 65    Vidhwath Kaverappa       Bowler       India                  20.0
# 66          Vishnu Vinod    WK-Batter       India                  20.0
# 109        Vaibhav Arora   Allrounder       India                  20.0
# 122       Vivrant Sharma   Allrounder       India                  20.0
# 227         Vicky Ostwal   Allrounder       India                   NaN
# 250        Vijay Shankar   Allrounder       India                   NaN
# 282          Virat Kohli       Batter       India                   NaN
# 295       Venkatesh Iyer   Allrounder       India                   NaN
# 297  Varun Chakaravarthy       Bowler       India                   NaN
#
#      final price (in lacs) franchise    status
# 44                     NaN       NaN    UNSOLD
# 65                    20.0      PBKS      SOLD
# ...

# %%
d = {"Bowler": 'Fast Bowler'}
df["nationality"] = df["nationality"].map(d)
df.head(20)
# Out:
#                      name player style nationality  base price (in lacs)  \
# 0            Harshit Rana       Bowler         NaN                   NaN
# 1               Ekant Sen       Batter         NaN                  20.0
# 2           Wayne Parnell   Allrounder         NaN                  75.0
# 3         Shakib Al Hasan   Allrounder         NaN                 150.0
# 4                Joe Root       Batter         NaN                 100.0
# 5            Abdul Basith   Allrounder         NaN                  20.0
# 6         Prashant Chopra   Allrounder         NaN                  20.0
# 7            Akeal Hosein       Bowler         NaN                 100.0
# 8            Raghav Goyal       Bowler         NaN                  20.0
# 9    Yudhvir Singh Charak   Allrounder         NaN                  20.0
# 10              Luke Wood       Bowler         NaN                 100.0
# 11     Dilshan Madushanka       Bowler         NaN                  50.0
# ...

# %%
df = df.replace({"player style": d})
df.head()
# Out:
#               name player style nationality  base price (in lacs)  \
# 0     Harshit Rana  Fast Bowler         NaN                   NaN
# 1        Ekant Sen       Batter         NaN                  20.0
# 2    Wayne Parnell   Allrounder         NaN                  75.0
# 3  Shakib Al Hasan   Allrounder         NaN                 150.0
# 4         Joe Root       Batter         NaN                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
columns_to_show = ["status", "player style", "franchise"]

df.groupby(["name"])[columns_to_show].describe(percentiles=[])
# Out:
#                             status                       player style         \
#                              count unique       top freq        count unique
# name
# Abdul Basith                     1      1      SOLD    1            1      1
# Abdul Samad                      1      1  RETAINED    1            1      1
# Abhimanyu Easwaran               1      1    UNSOLD    1            1      1
# Abhinav Manohar Sadarangani      1      1  RETAINED    1            1      1
# Abhishek Sharma                  1      1  RETAINED    1            1      1
# ...                            ...    ...       ...  ...          ...    ...
# Yash Thakur                      1      1      SOLD    1            1      1
# Yashasvi Jaiswal                 1      1  RETAINED    1            1      1
# Yudhvir Singh Charak             1      1      SOLD    1            1      1
# Yuvraj Chudasama                 1      1    UNSOLD    1            1      1
# ...

# %%
df2 = pd.crosstab(df["franchise"], df["status"])
df2
# Out:
# status     RETAINED  SOLD
# franchise
# CSK              18     7
# DC               19     5
# GT               18     7
# KKR              11     8
# LSG              15    10
# MI               15     8
# PBKS             16     6
# RCB              18     7
# RR               16     9
# SRH              12    13

# %%
df2 = pd.crosstab(df["franchise"], df["status"], normalize=True)
df2
# Out:
# status     RETAINED      SOLD
# franchise
# CSK        0.075630  0.029412
# DC         0.079832  0.021008
# GT         0.075630  0.029412
# KKR        0.046218  0.033613
# LSG        0.063025  0.042017
# MI         0.063025  0.033613
# PBKS       0.067227  0.025210
# RCB        0.075630  0.029412
# RR         0.067227  0.037815
# SRH        0.050420  0.054622

# %%
import seaborn as sns

# %%
sns.countplot(x='status', hue='franchise', data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>
