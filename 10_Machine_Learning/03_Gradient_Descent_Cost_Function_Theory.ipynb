# %% [markdown]
# # Gradient Descent Theory

# %% [markdown]
# Mean square error cost function gradient descent & learning rate, these are some of the important concepts in ML
#
# We'll not be implementing the gradient descent while solving the actual machine learning problem but the reason behind
# learning gradient descent is that we should know some of the internals so that while using the sklearn or Scikit-learn
# library we know what's going on and use these libraries in a better way.
#
# During our linear algebra class in school days what we use to have was this equation:
#
# ![03_equation.JPG](attachment:7e08ad44-6525-45f4-b09c-83d94bd007bf.JPG)

# %% [markdown]
# And X as an input and we use to compute the value of y:
#
# ![03_equation1.JPG](attachment:cafaf7fa-bb0f-48a1-bd7c-f07580219ef1.JPG)

# %% [markdown]
# Where the way you derive 9 is by multiplying  3 of x with 2 of y which will be 6 and plus this 6 with +3 of y which will be 9 in the resultant of Y.
#
# Incase of ML however, we have observation of training dataset which is your input and output:
#
# $$ X = [1,2,3,4,5] $$
#
# $$ Y = [5,7,9,11,13] $$

# %% [markdown]
# By using that you try to derive an equation also known as prediction function:
#
# $$ y=2x+3$$

# %% [markdown]
# So that you can use this equation to predict future values of x.

# %% [markdown]
# Incase of our problem of predicting home prices we saw the intial linear regression that we have area and price:
# $$ area = [2600,3000,3200,3600,4000]$$
#
# $$ price = [550k,565k,610k,680k,725k]$$
#
# and using that we came with this equation:
#
# $$price = 135.78*area+180.616.43 $$

# %% [markdown]
# Now here we have:
#
# ![03_homeprice.JPG](attachment:deae3660-1a40-4d66-9b1d-8f1f83e5c545.JPG)

# %% [markdown]
# We have the home prices in monroe township adn have plotted them on this chart and what we are going to look at is that how can we derive this equation given these input and outputs so out goal is to derive this equation:
#
# ![03_equation2.JPG](attachment:0f32d2f6-ebc5-4e46-a375-985231f57acd.JPG)

# %% [markdown]
# That equation is nothing but this blue line which is the best fit line going through all these data points and these data points scattered so it is not possible to draw a perfect line but try to draw line which is kind of a best fit:
#
# ![01_fig2.JPG](attachment:3545b63c-aeb3-4486-98e9-a60264d2eda2.JPG)
#
# But the problem here is we might have so many line like:
#
# ![01_fig4.JPG](attachment:83baef91-7916-47b1-9860-495a7cf566d2.JPG)
#
# That can potentially go through these data points, our data set here is very simple if we have like a very heavy dataset and if it is like scattered all over the place then drawing these lines become even more difficult so how do we know which of these lines is the best fit line and that is the main problem that we are going to solve today.

# %% [markdown]
# So one way is you draw any random line and then from your actual data point you calculate the error between that datapoint and the datapoint predicted by your line so called it a delta and then you collect all these deltas and square them, the reason you want to square them is these deltas could be negative also and if you dont square them and just add them then the results might be skewed.
#
# ![03_fig.JPG](attachment:d7fe7bf2-af94-4947-b312-1186e6c1511a.JPG)
#
# After that you sum them up and divided by n so n here is 5 as it is the number of data points we have available and the result is called mean square error and mean square error is nothing but our actual data point minus the predicted datapoint and you square it sum it and then divide it by n:
#
# ![03_equation3.JPG](attachment:e7150d15-1f2d-4b32-8000-9e3451e7a391.JPG)
#
# This mean square error is also called a cost function:
#
# ![03_equation4.JPG](attachment:32dca23e-5b52-469b-a8f5-cfd130e378c9.JPG)
#
# There are different type of cost funtions as well but mean square error is the most popular one and here y predicted is replaced by mx plus b becuase y is equal to mx plus b so that is the equation for mean square error.

# %% [markdown]
# Now we initially saw that that there are so many different lines that we can draw. We are not going to try every permutation and combination of m and b because that is very inefficient, we want to take some efficient approach where in very less iteration you can reach your answer and gradient descent is that algorithm that helps you find best fit line in very less number of iteration or in a very efficient way:
#
# # Gradient Descent is an algorithm that finds best fit line for given training data set.

# %% [markdown]
# ![03_fig2.JPG](attachment:1e63370d-22a2-4fc9-8a9f-a563f05fc5cc.JPG)
#
# Now lets look at the working of gradient descent and for that we have plotted m and b against the MSE(mean square error) or a cost function so here we have drawn different values of m and here there are different values of p which is the intercept and for every values of m and b we will find some cost so if we keep on plotting those points here and if we create a plane out of it then it will look like this, it will be like a ball and what we want to do is we want to start with some value of m and b and people usually starts with zero so here you can see this point has m and zero and b as zero and from that point you calculate the cost so lets say the cost is thousand and then you reduce the value of m and b by some amount and we'll see what that amount is later on so you take kind of like a mini step you came here and you will see that the error is now reduced to somewhere around 900  and then again you reduced it by taking one more step, and you keep on taking these steps until you reach this point at the center which is the **minima** and here the error is minimum and once you reach that you will found the answers because you will use that m and b in your prediction function.

# %% [markdown]
# Now i have plotted these different lines:
#
# ![03_fig3.JPG](attachment:66ee4e03-8cf3-41e1-b44b-401889467cc8.JPG)
#
# and these different lines will have different values of m and b lets say that orange has m1 b1 so m1b1 will be there somewhere and blue line will have m2b2 and it will that red dot on blue line and red line will be m3b3 and it will be somewhere on the upper plot.
#
# so you can have like so many numerous lines which can create that upper gradient MSE plot.
#
# Now we said that we will take these baby steps but how exactly we do it because visually it sounds easy but mathematically when we give this task to your computer then we have to come up with some conrete approach so here is a nice visualization of how we can reduce m and b and reach the best fit line:
#
# ![03_fig4.JPG](attachment:fc187319-882a-4cd9-ae34-1f7fc2699c2b.JPG)

# %% [markdown]
# Lets look at how we are going to take those baby steps:
#
# ![03_fig5.JPG](attachment:d5165411-8d67-403d-8806-79fba46c0cf9.JPG)
#
# Here we have these 2 charts and if we look at that 3D plot from that b-side direction so what we will see is a chart of b against cost and that will be this curvature b figure and similarly if we look the 3d plot from b-side direction so the chart will look something like m figure and in both the cases we are starting at the top 3D plot which is that star in both m and b figures and then taking these mini steps and trying to reach these minimum points which is that red dot in both m and b figures.

# %% [markdown]
# Now how do we take these steps so one approach is lets say we take fix size steps as shown in figure:
#
# ![03_fig6.JPG](attachment:780f09ff-35e8-4f8d-86ba-1431f2691072.JPG)
#
# So here if we plot if we plot the line against b where we are taking fixed size steps on b but the problem that it can create is by taking these steps we might the global minima and we might just miss it as shown in figure with a red dot and by this our gradient descent will never converge and from this point it will just start going up and up and upto so on and we will never know where will be the global minima so this approach is not going to work.
#
# What can work is if we take steps like this as shown in figure:
#
# ![03_fig7.JPG](attachment:b64c8325-90b3-4b19-812d-922ee04f75f9.JPG)
#
# So here in each step im following the curvature of my chart and also as i reach near to my red point/dot we can then see that the step size is reducing and if we do something like this then we reach that global minima now ho we do that so at each point we need to calculate the slope as shown in figure:
#
# ![03_fig8.JPG](attachment:a2e13c81-d947-4b5e-bdec-cc7660d0f87d.JPG)

# %% [markdown]
# So for example at the point beneath the star the slope will be that straight line, this is the tangent at the curvature and the 2nd blue dot on the upside of the red dot the slope will be that line.
#
# Once we have a slope then we know which direction we need to go in for example if you look at the 2nd blue dot line and if im at the blue dot then i know that i have to go through that direction and then there is something called a learning rate which you can use in conjuction with that slope to take that step and reach the next point.
#
# Now we have to get into the calculus little bit becuase calculus allows you to figure out these baby steps and when you are talking about these slopes, this slope is nothing but a derivative of b wrt MSE cost function.

# %% [markdown]
# Lets look at what is derivatives,  So derivatives are all about slopes:
#
# ![03_fig9.JPG](attachment:6e310933-a6a4-4286-9fec-9d8a3ed98ef9.JPG)
#
# ![03_fig10.JPG](attachment:0c76bf65-e67d-43bd-bbfc-26f6abdd565f.JPG)

# %% [markdown]
# For more information visit: www.mathisfun.com

# %% [markdown]
# Also look into partial derivatives

# %% [markdown]
# For more concepts of calculus follow 3blue1brown youtube channel

# %% [markdown]
# derivate of this function: $f(x)=x^3$
#
# will be:
# $\frac{d}{dx}x^3=3x^3 $

# %% [markdown]
# Derivative of: $f(x,y)=x^3+y^3 $
#
# it will be: $\frac{∂f}{∂x}=3x^2+0=3x^2 $
#
# $\frac{∂f}{∂y}=0+2y=2y$

# %% [markdown]
# ![03_eq.JPG](attachment:c08baad6-b264-4001-807f-e13cbcc5212b.JPG)
